# %%
import pandas as pd
import time
import matplotlib.pyplot as plt
from pyspark.sql import SparkSession, types
import pyspark.sql.functions as F
from  pyspark.sql.functions import col

spark = (
    SparkSession.builder.config("spark.sql.debug.maxToStringFields", 100)
    .appName("reviews")
    .getOrCreate()
)

# steam_reviews_filepath = "../data/cleaned_steam_reviews/game_id={70,240,420,620}"
steam_reviews_filepath = "../data/cleaned_steam_reviews"
steam_games_filepath = "../data/cleaned_steam_games"
# Out:
# 23/11/24 15:19:12 WARN Utils: Your hostname, Alexs-MacBook-Pro-4.local resolves to a loopback address: 127.0.0.1; using 142.58.162.207 instead (on interface en0)
# 23/11/24 15:19:12 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/11/24 15:19:13 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## Load Data

# %%
steam_reviews = spark.read.parquet(steam_reviews_filepath)

# %%
steam_games = spark.read.parquet(steam_games_filepath)

steam_games.printSchema()
# Out:
# root
#  |-- url: string (nullable = true)
#  |-- types: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- desc_snippet: string (nullable = true)
#  |-- recent_reviews: string (nullable = true)
#  |-- all_reviews: string (nullable = true)
#  |-- release_date: date (nullable = true)
#  |-- developer: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- popular_tags: string (nullable = true)
#  |-- game_details: string (nullable = true)
#  |-- languages: string (nullable = true)
#  |-- achievements: integer (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- game_description: string (nullable = true)
#  |-- mature_content: string (nullable = true)
#  |-- minimum_requirements: string (nullable = true)
#  |-- recommended_requirements: string (nullable = true)
#  |-- original_price: string (nullable = true)
#  |-- discount_price: string (nullable = true)
#  |-- game_id: string (nullable = true)

# %%
steam_games.select([F.count(F.when(~F.isnull(c), c)).alias(c) for c in steam_games.columns]).show()
# Out:
# [Stage 3:===================================================>       (7 + 1) / 8]
# +-----+-----+-----+------------+--------------+-----------+------------+---------+---------+------------+------------+---------+------------+-----+----------------+--------------+--------------------+------------------------+--------------+--------------+-------+
# |  url|types| name|desc_snippet|recent_reviews|all_reviews|release_date|developer|publisher|popular_tags|game_details|languages|achievements|genre|game_description|mature_content|minimum_requirements|recommended_requirements|original_price|discount_price|game_id|
# +-----+-----+-----+------------+--------------+-----------+------------+---------+---------+------------+------------+---------+------------+-----+----------------+--------------+--------------------+------------------------+--------------+--------------+-------+
# |38020|38020|38020|       37981|          3275|      28281|         391|    37619|    32985|       37855|       37541|    27222|        9646|26760|           26999|          5255|               16703|                   16510|         25434|         10928|  38020|
# +-----+-----+-----+------------+--------------+-----------+------------+---------+---------+------------+------------+---------+------------+-----+----------------+--------------+--------------------+------------------------+--------------+--------------+-------+

# %%
steam_games.select("release_date").distinct().show()
# Out:
# +------------+
# |release_date|
# +------------+
# |  2016-01-01|
# |        null|
# |  2017-01-01|
# |  2021-01-01|
# |  2019-01-01|
# |  2020-01-01|
# |  2018-01-01|
# |  2022-01-01|
# |  2019-03-01|
# +------------+

# %%
steam_games.where(steam_games['release_date'].isNotNull()).orderBy(F.desc(steam_games['release_date'])).show(100)
# Out:
# +--------------------+-----+--------------------+--------------------+--------------+-----------+------------+------------------------+------------------------------------+--------------------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+------------------------+--------------------+--------------------+-------+
# |                 url|types|                name|        desc_snippet|recent_reviews|all_reviews|release_date|               developer|                           publisher|        popular_tags|        game_details|           languages|achievements|               genre|    game_description|      mature_content|minimum_requirements|recommended_requirements|      original_price|      discount_price|game_id|
# +--------------------+-----+--------------------+--------------------+--------------+-----------+------------+------------------------+------------------------------------+--------------------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+------------------------+--------------------+--------------------+-------+
# |https://store.ste...|  app|      Captain's Tail|Dash into action ...|          null|       null|  2022-01-01|           Biting Mascot|                Biting Mascot,Bit...|Action,Adventure,...|Single-player,Par...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 977580|
# |https://store.ste...|  app|   Return to Nangrim|Return to Nangrim...|          null|       null|  2021-01-01|               Sycoforge|                 Sycoforge,Sycoforge|Adventure,Action,...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 860210|
# |https://store.ste...|  app|          CHROMATOSE|An Indie Visual N...|          null|       null|  2021-01-01|                 Akabaka|                     Akabaka,Akabaka|RPG,Strategy,Indi...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1003900|
# |https://store.ste...|  app|            Backbone|Backbone is a noi...|          null|       null|  2020-01-01|                  EggNut|                       EggNut,EggNut|Indie,Adventure,P...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 865610|
# |https://store.ste...|  app|         The Sojourn|A tale of light, ...|          null|       null|  2020-01-01|          Shifting Tides|                Iceberg Interacti...|Indie,Puzzle,Adve...|       Single-player|English,French,It...|        null|     Adventure,Indie| About This Game ...|                null|Minimum:,OS:,Wind...|    Recommended:,OS:,...|                null|                null| 794960|
# |https://store.ste...|  app|     Spectrum's Path|A dark conquest h...|          null|       null|  2020-01-01|             BreakerZero|                Dedderomedia,Dedd...|           RPG,Indie|Single-player,Par...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1005100|
# |https://store.ste...|  app|      After the Fall|From the creators...|          null|       null|  2020-01-01|           Vertigo Games|                Vertigo Games,Ver...|Action,Adventure,...|Single-player,Mul...|English,French,It...|        null|    Action,Adventure| About This Game ...| Mature Content D...|Minimum:,OS:,Wind...|    Recommended:,OS:,...|                null|                null| 751630|
# |https://store.ste...|  app|    Immortal Emperor|A deeply satisfyi...|          null|       null|  2020-01-01|             H. Hochkins|                Urban Meadows Pub...|      Strategy,Indie|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 812780|
# |https://store.ste...|  app|               Adome|ADOME is an actio...|          null|       null|  2020-01-01|          Timsea Studios|                BadLand Publishin...|    Action,Adventure|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 912690|
# |https://store.ste...|  app|       The First Men|A real-time 4x st...|          null|       null|  2020-01-01|          Gathering Tree|                                null|Strategy,Simulati...|Single-player,Mul...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 700820|
# |https://store.ste...|  app|Evil Genius 2: Wo...|A satirical spy-f...|          null|       null|  2020-01-01|               Rebellion|                 Rebellion,Rebellion|Strategy,Simulati...|Single-player,Ste...|English,French,It...|        null| Simulation,Strategy| About This Game ...|                null|                null|                    null|                null|                null| 700600|
# |https://store.ste...|  app|      Tick Tick Pass|The ultimate triv...|          null|       null|  2020-01-01|      Chequered Ink Ltd.|                Chequered Ink Ltd...|        Indie,Casual|Single-player,Mul...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 655520|
# |https://store.ste...|  app|          OddBallers|Fast and frantic ...|          null|       null|  2020-01-01|              Game Swing|                Game Swing,Game S...|Indie,Action,Spor...|Multi-player,Onli...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1064070|
# |https://store.ste...|  app|Nehrim: At Fate's...|Nehrim: At Fate's...|          null|       null|  2020-01-01|                  SureAI|                       SureAI,SureAI|RPG,Action,Adventure|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1014940|
# |https://store.ste...|  app|22 Racing Series ...|Welcome to 'Real-...|          null|       null|  2020-01-01|     GOATi Entertainment|                GOATi Entertainme...|Strategy,Indie,Si...|Single-player,Onl...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 422890|
# |https://store.ste...|  app|Fall Guys: Ultima...|Fall Guys: Ultima...|          null|       null|  2020-01-01|              Mediatonic|                Devolver Digital,...|Casual,Sports,Ind...|Online Multi-Play...|English,French,It...|        null|Casual,Indie,Mass...| About This Game ...|                null|                null|                    null|                null|                null|1097150|
# |https://store.ste...|  app|       Psychonauts 2|Razputin Aquato, ...|          null|       null|  2020-01-01|    Double Fine Produ...|                Xbox Game Studios...|Adventure,Action,...|Single-player,Ful...|English,French,It...|        null|    Action,Adventure| About This Game ...|                null|Minimum:,Requires...|    Recommended:,Requ...|                null|                null| 607080|
# |https://store.ste...|  app|      WHAT THE GOLF?|The anti-golf gam...|          null|       null|  2020-01-01|                 Triband|                Fig Publishing In...|Funny,Intentional...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 785790|
# |https://store.ste...|  app|       The Iron Oath|The Iron Oath is ...|          null|       null|  2020-01-01|     Curious Panda Games|                Curious Panda Gam...|RPG,Indie,Strateg...|Single-player,Ste...|             English|        null|Adventure,Indie,R...| About This Game ...|                null|                null|                    null|                null|                null| 699330|
# |https://store.ste...|  app|            Refactor|Refactor is a phy...|          null|       null|  2020-01-01|      NextGen Pants, Inc|                NextGen Pants, In...|Action,Adventure,...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 342730|
# |https://store.ste...|  app|                Embr|Become an Embr Re...|          null|       null|  2020-01-01|              Muse Games|                Muse Games,Muse G...|Early Access,Acti...|Single-player,Mul...|             English|        null|Action,Indie,Simu...| About This Game ...|                null|                null|                    null|                null|                null|1062830|
# |https://store.ste...|  app|           Unsighted|The few androids ...|          null|       null|  2020-01-01|       Studio Pixel Punk|                Studio Pixel Punk...|Action,Adventure,...|Single-player,Loc...|English,Portugues...|        null|Action,Adventure,...| About This Game ...|                null|                null|                    null|                null|                null|1062110|
# |https://store.ste...|  app|          Gooberries|Gooberries is a s...|          null|       null|  2020-01-01|              Mash Patch|                Mash Patch,Mash P...|Early Access,Indi...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1081070|
# |https://store.ste...|  app|This is the Zodia...|Story-driven FPS ...|          null|       null|  2020-01-01|        Punk Punch Games|                PlayWay S.A.,Play...|Adventure,Indie,V...|       Single-player|English,French,It...|        null|     Adventure,Indie|" About This Game...| this is the Zodi...|   stealth mechanics|     detective mode a...| stylized graphic...| one of the best ...| 907710|
# |https://store.ste...|  app|   The Vrennman Case|The Vrennman Case...|          null|       null|  2020-01-01|           Game Kombinat|                Game Kombinat,Gam...|Adventure,Indie,C...|Single-player,Par...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 857230|
# |https://store.ste...|  app|           Batbarian|Batbarian is an a...|          null|       null|  2020-01-01|      Unspeakable Pixels|                DANGEN Entertainm...|Indie,Adventure,A...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 837460|
# |https://store.ste...|  app|The Wizards - Dar...|Travel in time to...|          null|       null|  2020-01-01|           Carbon Studio|                Carbon Studio,Car...|Action,Adventure,...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1103860|
# |https://store.ste...|  app|             Sapiens|Evolve your primi...|          null|       null|  2020-01-01|            Majic Jungle|                Majic Jungle,Maji...|Indie,Strategy,Si...|Single-player,Mul...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1060230|
# |https://store.ste...|  app|Otto and the Anci...|Otto and the Anci...|          null|       null|  2020-01-01|    Obvious Gravity G...|                Obvious Gravity G...|Action,Adventure,...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 863720|
# |https://store.ste...|  app|           Othercide|Set in an etherea...|          null|       null|  2020-01-01|          Lightbulb Crew|                 LBC Games,LBC Games|Strategy,Indie,Ta...|Single-player,Par...|English,French,Si...|        null|      Indie,Strategy| About This Game ...|                null|Minimum:,OS:,Wind...|    Recommended:,OS:,...|                null|                null| 798490|
# |https://store.ste...|  app|          Cris Tales|Play the debut de...|          null|       null|  2020-01-01|    Dreams Uncorporat...|                Modus Games,Modus...|Adventure,RPG,Act...|Single-player,Par...|English,French,Ge...|        null|Action,Adventure,RPG| About This Game ...|                null|Minimum:,OS:,OS V...|    Recommended:,OS:,...|Enjoy the Demo to...|                null|1079830|
# |https://store.ste...|  app|Letters - a writt...|Letters - a writt...|          null|       null|  2020-01-01|          5am Games GmbH|                5am Games GmbH,5a...|Adventure,Indie,C...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1033080|
# |https://store.ste...|  app|               Sable|Sable is a coming...|          null|       null|  2020-01-01|               Shedworks|                   Raw Fury,Raw Fury|Indie,Adventure,F...|Single-player,Ful...|English,French,Ge...|        null|     Adventure,Indie| About This Game ...|                null|Minimum:,OS:,Wind...|    Recommended:,OS:,...|                null|                null| 757310|
# |https://store.ste...|  app|Age of Fear 4: Th...|Play as Angela, a...|          null|       null|  2020-01-01|           Leslaw Sliwko|                Age of Fear,Age o...|Strategy,Story Ri...|Single-player,Loc...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 431950|
# |https://store.ste...|  app|    Brigador Killers|BRIGADOR KILLERS ...|          null|       null|  2020-01-01|    Stellar Jockeys,G...|                Stellar Jockeys,S...|Action,Indie,Violent|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 903930|
# |https://store.ste...|  app|             Privacy|Privacy is a narr...|          null|       null|  2020-01-01|                 Codalyn|                     Codalyn,Codalyn|Adventure,Indie,S...|Single-player,Ful...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 887700|
# |https://store.ste...|  app|       Brutal Scales|Tactics Role Play...|          null|       null|  2020-01-01|      Missiles are Magic|                Missiles are Magi...|  Strategy,RPG,Indie|Single-player,Ful...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1091020|
# |https://store.ste...|  app|    Flipper Mechanic|Become a Flipper ...|          null|       null|  2020-01-01|               SimFabric|                 SimFabric,SimFabric|Strategy,Indie,Si...|Single-player,Par...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1068570|
# |https://store.ste...|  app|  Twisty Tumble (VR)|It's a tricky puz...|          null|       null|  2020-01-01|       Pixel After Pixel|                Pixel After Pixel...|Strategy,Indie,Si...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1074990|
# |https://store.ste...|  app|               Haven|They escaped to a...|          null|       null|  2020-01-01|         The Game Bakers|                The Game Bakers,T...|RPG,Indie,Adventu...|Single-player,Loc...|English,French,It...|        null| Adventure,Indie,RPG| About This Game ...|                null|                null|                    null|                null|                null| 983970|
# |https://store.ste...|  app|            Asterion|ASTERION is a 3D ...|          null|       null|  2020-01-01|       Glass Bear Studio|                Glass Bear Studio...|Action,Adventure,...|Single-player,Ful...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 955940|
# |https://store.ste...|  app|  Circuit Superstars|Circuit Superstar...|          null|       null|  2020-01-01|     Original Fire Games|                Square Enix,Squar...|              Racing|Single-player,Mul...|English,French,It...|        null|              Racing| About This Game ...|                null|    Minimum:,OS:,tbc|    Recommended:,OS:,tbc|                null|                null|1097130|
# |https://store.ste...|  app|        Tormentum II|Tormentum II is a...|          null|       null|  2020-01-01|            OhNoo Studio|                OhNoo Studio,OhNo...|Adventure,Indie,C...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 931060|
# |https://store.ste...|  app|Stronghold: Warlords|Besiege Great Kha...|          null|       null|  2020-01-01|         FireFly Studios|                FireFly Studios,F...|Strategy,Simulati...|Single-player,Onl...|English,French,It...|        null| Simulation,Strategy| About This Game ...|                null|Minimum:,Addition...|    Recommended:,Addi...|                null|                null| 907650|
# |https://store.ste...|  app|               SOLOS|What’s real? What...|          null|       null|  2020-01-01|              Pixelsplit|                Pixelsplit,Pixels...|Adventure,Indie,G...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 809060|
# |https://store.ste...|  app|Heroes of the Mul...|Explore the dange...|          null|       null|  2020-01-01|                Team Umi|                   Team Umi,Team Umi|Free to Play,Mass...|Multi-player,Onli...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1061670|
# |https://store.ste...|  app| Little Witch Nobeta|Play as the cute ...|          null|       null|  2020-01-01|            Pupuya Games|                Pupuya Games,Pupu...|Action,Indie,Cute...|Single-player,Ful...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1049890|
# |https://store.ste...|  app|Operencia: The St...|Operencia: The St...|          null|       null|  2020-01-01|             Zen Studios|                Zen Studios,Zen S...|RPG,Grid-Based Mo...|Single-player,Ste...|English,French,It...|        null|                 RPG| About This Game ...|                null|Minimum:,Requires...|    Recommended:,Requ...|                null|                null| 985950|
# |https://store.ste...|  app| Industries of Titan|Create a sprawlin...|          null|       null|  2020-01-01|    Brace Yourself Games|                Brace Yourself Ga...|Simulation,Strate...|       Single-player|English,French,Ge...|        null|Indie,Simulation,...|" About This Game...| with art by Sir ...| music by Danny B...|     and audio by Pow...|                null|                null| 427940|
# |https://store.ste...|  app|       Weaving Tides|Ride on the backs...|          null|       null|  2020-01-01|     Follow the Feathers|                Follow the Feathe...|Action,Adventure,...|Single-player,Ful...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1075170|
# |https://store.ste...|  app|         Spiritfarer|Spiritfarer is a ...|          null|       null|  2020-01-01|     Thunder Lotus Games|                Thunder Lotus Gam...|Simulation,Advent...|Single-player,Loc...|      English,French|        null|Adventure,Indie,S...| About This Game ...|                null|                null|                    null|                null|                null| 972660|
# |https://store.ste...|  app| Destroy All Humans!|The cult-classic ...|          null|       null|  2020-01-01|    Black Forest Game...|                THQ Nordic,THQ No...|Action,Gore,Adven...|Single-player,Ste...|English,French,It...|        null|    Action,Adventure| About This Game ...| Mature Content D...|Minimum:,Requires...|    Recommended:,Requ...|                null|                null| 803330|
# |https://store.ste...|  app|         Eons of War|In this fast-pace...|          null|       null|  2020-01-01|      Vasinov Games, LLC|                Vasinov Games, LL...|Strategy,Space,Gr...|Single-player,Mul...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 947460|
# |https://store.ste...|  app|          Per Aspera|Per Aspera is a n...|          null|       null|  2020-01-01|         Tlön Industries|                   Raw Fury,Raw Fury|Strategy,Indie,Si...|       Single-player|English,French,It...|        null|Indie,Simulation,...| About This Game ...|                null|Minimum:,Requires...|    Recommended:,Requ...|                null|                null| 803050|
# |https://store.ste...|  app|               GUILT|Multiplayer third...|          null|       null|  2020-01-01|     Outer Brain Studios|                Outer Brain Studi...|Adventure,RPG,Ind...|Single-player,Mul...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1047950|
# |https://store.ste...|  app|Shooting Champion VR|A game which simu...|          null|       null|  2019-03-01|苏州光年数码科技有限公司|苏州光年数码科技有限公司,苏州光年...|       Casual,Sports|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 921790|
# |https://store.ste...|  app|Alaloth - Champio...|Set in a vibrant ...|          null|       null|  2019-01-01|      Gamera Interactive|                Gamera Interactiv...|Adventure,RPG,Str...|Single-player,Loc...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 919360|
# |https://store.ste...|  app|Herakles and the ...|                 NaN|          null|       null|  2019-01-01|            Becker Games|                                null|Action,Adventure,...|Single-player,Dow...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1103370|
# |https://store.ste...|  app|      Summer in Mara|‘Summer in Mara’ ...|          null|       null|  2019-01-01|                  Chibig|                       Chibig,Chibig|Adventure,Indie,S...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 962580|
# |https://store.ste...|  app|Princesses Never ...|Play as Erica, pr...|          null|       null|  2019-01-01|              AVANTGARDE|                Kagura Games,Kagu...|RPG,Indie,Anime,J...|Single-player,Ste...|English,Simplifie...|        null|           Indie,RPG| About This Game ...| Mature Content D...|                null|                    null|                null|                null|1058060|
# |https://store.ste...|  app|  Space of One Drama|The story of a fa...|          null|       null|  2019-01-01|                  Ehnenu|                       Ehnenu,Ehnenu|Adventure,Indie,C...|Single-player,Ful...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 852610|
# |https://store.ste...|  app|     Crumbling World|A Dark Fantasy Lo...|          null|       null|  2019-01-01|              Dani Marti|                 Dume Arts,Dume Arts|   Action,RPG,Casual|Single-player,Ful...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1003560|
# |https://store.ste...|  app|The Church in the...|An action/infiltr...|          null|       null|  2019-01-01|    Paranoid Productions|                Fellow Traveller,...|Indie,Adventure,A...|Single-player,Ful...|             English|        null|Action,Adventure,...| About This Game ...|                null|                null|                    null|                null|                null| 339830|
# |https://store.ste...|  app|    Sandbox Anything|A creative buildi...|          null|       null|  2019-01-01|               Fizzostia|                 Fizzostia,Fizzostia|Early Access,Earl...|Single-player,Mul...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1054370|
# |https://store.ste...|  app|       Vestaria Saga|A prince in fligh...|          null|       null|  2019-01-01|        Vestaria Project|                DANGEN Entertainm...|RPG,Strategy,Simu...|Single-player,Par...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 694770|
# |https://store.ste...|  app|     Fly Punch Boom!|Smash your friend...|          null|       null|  2019-01-01|        Jollypunch Games|                Jollypunch Games,...|Action,Indie,Anim...|Single-player,Mul...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1051960|
# |https://store.ste...|  app|            Polyroll|The roly poly wit...|          null|       null|  2019-01-01|        Spicy Gyro Games|                Shiny Dolphin Gam...|Indie,Platformer,...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 743850|
# |https://store.ste...|  app|            Wildfire|Master the elemen...|          null|       null|  2019-01-01|         Sneaky Bastards|                Sneaky Bastards,S...|Indie,Stealth,Pix...|Single-player,Sha...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 431940|
# |https://store.ste...|  app|        Torn Asunder|Tear off their li...|          null|       null|  2019-01-01|          Farhan Qureshi|                Farhan Qureshi,Fa...|Action,Indie,Violent|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 911850|
# |https://store.ste...|  app|             Retimed|Dash and dodge bu...|          null|       null|  2019-01-01|             Team Maniax|                Stray Fawn Studio...|Action,Indie,2D,F...|Single-player,Mul...|English,French,It...|        null| Action,Casual,Indie| About This Game ...|                null|                null|                    null|                null|                null| 760810|
# |https://store.ste...|  app|She Dreams Elsewhere|You wake up in a ...|          null|       null|  2019-01-01|           Studio Zevere|                Studio Zevere,Stu...|Indie,Adventure,R...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 492540|
# |https://store.ste...|  app|               Stela|Stela is a cinema...|          null|       null|  2019-01-01|             SkyBox Labs|                SkyBox Labs,SkyBo...|Adventure,Indie,P...|Single-player,Ful...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1048600|
# |https://store.ste...|  app|        The Unliving|The Unliving is a...|          null|       null|  2019-01-01|      RocketBrush Studio|                RocketBrush Studi...|Indie,Action,RPG,...|Single-player,Ful...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 986040|
# |https://store.ste...|  app|Trapped on Monste...|Stuck working as ...|          null|       null|  2019-01-01|    Lovely Pretty Ult...|                Kagura Games,Kagu...|RPG,Indie,Anime,M...|       Single-player|English,Simplifie...|        null|           Indie,RPG| About This Game ...| Mature Content D...|Minimum:,OS:,Wind...|    Recommended:,OS:,...|                null|                null|1042020|
# |https://store.ste...|  app|Blackout: The Dar...|You have been par...|          null|       null|  2019-01-01|    MiniChimera Game ...|                MiniChimera Game ...|Indie,Adventure,R...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 875400|
# |https://store.ste...|  app|              Piposh|סדרת משחקי הקאלט ...|          null|       null|  2019-01-01|              Guillotine|                Guillotine,Guillo...|           Adventure|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1092950|
# |https://store.ste...|  app|    Bugs 'N Boo Hags|PAINT THE TOWN BL...|          null|       null|  2019-01-01|            Acrid Banana|                Illustrategy, LLC...|        Action,Indie|Single-player,Ful...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1066620|
# |https://store.ste...|  app|   Eye of the Temple|Eye of the Temple...|          null|       null|  2019-01-01|          Sanctum Dreams|                Sanctum Dreams,Sa...|Action,Adventure,...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 589940|
# |https://store.ste...|  app|               Jengo|A Point & Click i...|          null|       null|  2019-01-01|            Robot Wizard|                Plug In Digital,P...|Adventure,Indie,P...|Single-player,Par...|             English|        null|     Adventure,Indie|" About This Game...| clickety-click a...| you begin to loo...|     a disgruntled ga...| the one that wil...| and blister on h...| 671430|
# |https://store.ste...|  app|         Solar Purge|Blow away everyth...|          null|       null|  2019-01-01|           Hitscan Games|                Hitscan Games,Hit...|Action,RPG,Indie,...|Single-player,Co-...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 931450|
# |https://store.ste...|  app|Tokyo Snap (Cozy ...|Spend a week in T...|          null|       null|  2019-01-01|          Cozy Game Pals|                Cozy Game Pals,Co...|               Indie|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null|1016430|
# |https://store.ste...|  app|             Exo One|A strange signal....|          null|       null|  2019-01-01|              Exbleative|                Exbleative,Exblea...|Indie,Exploration...|Single-player,Ful...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 773370|
# |https://store.ste...|  app|         Railgunners|Railgunners is a ...|          null|       null|  2019-01-01|        Expresso Studios|                Expresso Studios,...|Action,Indie,Shoo...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 723130|
# |https://store.ste...|  app|       Retro Rockets|Retro Rockets is ...|          null|       null|  2019-01-01|          Emissive Games|                Emissive Games,Em...|Action,Indie,Sci-...|Multi-player,Co-o...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 921890|
# |https://store.ste...|  app|               Effie|Effie is a 3D act...|          null|       null|  2019-01-01|         Inverge Studios|                Inverge Studios,I...|Adventure,Action,...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 975950|
# |https://store.ste...|  app|          GIGABUSTER|"Fiery action pla...|          null|       null|  2019-01-01|                  WALLER|                       WALLER,WALLER|Action,Indie,Sci-...|Single-player,Ful...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 981830|
# |https://store.ste...|  app|Paranoia: Happine...|Lead a team of fo...|          null|       null|  2019-01-01|    Black Shamrock,Cy...|                Bigben Interactiv...|                 RPG|       Single-player|English,French,Ge...|        null|                 RPG| About This Game ...|                null|                null|                    null|                null|                null| 858030|
# |https://store.ste...|  app|          Dreadlands|Dreadlands is a t...|          null|       null|  2019-01-01|        Blackfox Studios|                   Fatshark,Fatshark|Strategy,Indie,Tu...|Single-player,Mul...|             English|        null|      Indie,Strategy| About This Game ...| Mature Content D...|Minimum:,OS:,Wind...|    Recommended:,OS:,...|                null|                null|1054690|
# |https://store.ste...|  app|HitchHiker - A My...|Hitchhiker is a m...|          null|       null|  2019-01-01|        Mad About Pandas|                Versus Evil,Versu...|     Adventure,Indie|       Single-player|English,French,It...|        null|     Adventure,Indie| About This Game ...|                null|                null|                    null|                null|                null|1003120|
# |https://store.ste...|  app|           Darksburg|Darksburg is a co...|          null|       null|  2019-01-01|             Shiro Games|                Shiro Games,Shiro...|Zombies,Medieval,...|Single-player,Mul...|English,French,Ge...|        null|        Action,Indie| About This Game ...|                null|                null|                    null|                null|                null| 939100|
# |https://store.ste...|  app|Touch Type Tale -...|With barbarians a...|          null|       null|  2019-01-01|     Pumpernickel Studio|                Pumpernickel Stud...|Indie,Strategy,Ty...|Single-player,Mul...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 909470|
# |https://store.ste...|  app|             Insatia|А carnivorous wor...|          null|       null|  2019-01-01|    Kozinaka,Weilard,...|                Kozinaka Labs,Koz...|Action,Indie,Simu...|Single-player,Loc...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 563530|
# |https://store.ste...|  app|    Codename Nemesis|Codename Nemesis ...|          null|       null|  2019-01-01|      Broken Helm Studio|                Broken Helm Studi...|    Action,RPG,Indie|Single-player,Pro...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 993530|
# |https://store.ste...|  app|        Shadow Force|Shadow Force is a...|          null|       null|  2019-01-01|               Gray Eyes|                 Gray Eyes,Gray Eyes|Action,Adventure,...|Single-player,Mul...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 883750|
# |https://store.ste...|  app|          Gym Empire|Gym Empire is a g...|          null|       null|  2019-01-01|         Chronik Spartan|                Chronik Spartan,C...|Simulation,Strate...|Single-player,Ste...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 756300|
# |https://store.ste...|  app|      Flowing Lights|Flowing Lights ca...|          null|       null|  2019-01-01|            Denis Dufour|                Denis Dufour,Deni...|        Action,Indie|Single-player,Ful...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 757820|
# |https://store.ste...|  app|    Felix The Reaper|Felix The Reaper ...|          null|       null|  2019-01-01|             Kong Orange|                Daedalic Entertai...|Indie,Adventure,P...|Single-player,Ste...|      English,German|        null|     Adventure,Indie| About This Game ...|                null|                null|                    null|                null|                null| 919410|
# |https://store.ste...|  app|Pursuit of Power®...|Pursuit of Power®...|          null|       null|  2019-01-01|    Precision Games, LLC|                Precision Games, ...|Indie,Strategy,Ac...|Single-player,Mul...|                null|        null|                null|                null|                null|                null|                    null|                null|                null| 546120|
# |https://store.ste...|  app|Shadow Over Isola...|“If you’re readin...|          null|       null|  2019-01-01|         Naughty Shinobi|                Forever Entertain...|Adventure,Indie,V...|Single-player,Ful...|             English|        null|     Adventure,Indie| About This Game ...| Mature Content D...|Minimum:,Requires...|    Recommended:,Requ...|                null|                null| 463940|
# |https://store.ste...|  app|Euro Truck Simula...|                 NaN|          null|       null|  2019-01-01|            SCS Software|                SCS Software,SCS ...|Simulation,Indie,...|Single-player,Dow...|English,German,Fr...|        null|    Indie,Simulation| About This Conte...|                null|Minimum:,OS:,Wind...|    Recommended:,OS:,...|                null|                null|1056760|
# +--------------------+-----+--------------------+--------------------+--------------+-----------+------------+------------------------+------------------------------------+--------------------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+------------------------+--------------------+--------------------+-------+
# only showing top 100 rows

# %% [markdown]
# ## Steam Reviews

# %%
def get_game_statistics_by_review_players(steam_reviews):
    playerTypeData = steam_reviews.select("app_id", "app_name", "author_steamid",
                                            "author_num_games_owned", "author_num_reviews", "author_playtime_forever",
                                            "author_playtime_last_two_weeks", "author_playtime_at_review", "author_last_played") \
                                    .where(col("author_steamid").isNotNull() \
                                                    & col("author_num_games_owned").isNotNull() \
                                                    & (col("author_num_reviews").isNotNull()) \
                                                    & (col("author_playtime_forever").isNotNull()) \
                                                    & (col("author_playtime_last_two_weeks").isNotNull()) \
                                                    & (col("author_playtime_at_review").isNotNull()) \
                                                    & (col("author_last_played").isNotNull())  )
    
    gameName = playerTypeData.select("app_id", "app_name").distinct()

    playerType = playerTypeData.groupBy(col("app_id")) \
                                .agg( \
                                    F.count("author_steamid").alias("review_count"), \
                                    F.avg("author_num_games_owned").alias("avg_num_games_owned"), \
                                    F.avg("author_num_reviews").alias("avg_num_reviews"), \
                                    F.avg("author_playtime_forever").alias("avg_playtime_forever"), \
                                    F.avg("author_playtime_last_two_weeks").alias("avg_playtime_last_two_weeks"), \
                                    F.avg("author_playtime_at_review").alias("avg_playtime_at_review"), \
                                    F.avg("author_last_played").alias("avg_last_played") \
                                )

    playerType = gameName.join(playerType, "app_id").orderBy(col("app_id").cast(types.IntegerType()))

    return playerType

# %%
playerType = get_game_statistics_by_review_players(steam_reviews)

# %% [markdown]
# ## Join Player Type and Steam Games

# %%
playerType_steamGames = steam_games.join(playerType, steam_games["game_id"] == playerType["app_id"])

# %%
playerType_steamGames.show(10)
# Out:
# +--------------------+-----+--------------------+--------------------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+------------------------+--------------+--------------+-------+------+--------------------+------------+-------------------+------------------+--------------------+---------------------------+----------------------+--------------------+
# |                 url|types|                name|        desc_snippet|      recent_reviews|         all_reviews|release_date|           developer|           publisher|        popular_tags|        game_details|           languages|achievements|               genre|    game_description|      mature_content|minimum_requirements|recommended_requirements|original_price|discount_price|game_id|app_id|            app_name|review_count|avg_num_games_owned|   avg_num_reviews|avg_playtime_forever|avg_playtime_last_two_weeks|avg_playtime_at_review|     avg_last_played|
# +--------------------+-----+--------------------+--------------------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+------------------------+--------------+--------------+-------+------+--------------------+------------+-------------------+------------------+--------------------+---------------------------+----------------------+--------------------+
# |https://store.ste...|  app|             Outlast|Hell is an experi...|Very Positive,(13...|Overwhelmingly Po...|        null|         Red Barrels|Red Barrels,Red B...|Horror,First-Pers...|Single-player,Ste...|English,French,It...|          14|Action,Adventure,...| About This Game ...| Mature Content D...|Minimum:,OS:,Wind...|    Recommended:,OS:,...|        $19.99|        $47.17| 238320|238320|             Outlast|       47810| 151.21819702991007|17.189186362685632|   986.3357874921564|         10.681154570173604|     466.1542773478352|1.5385805627194312E9|
# |https://store.ste...|  app|  Volgarr the Viking|Return to the Gol...|                null|Very Positive,(1,...|        null|Crazy Viking Studios|Adult Swim Games,...|Platformer,Diffic...|Single-player,Ste...|             English|          20|Action,Adventure,...| About This Game ...|                null|                null|                    null|         $9.99|        $24.72| 247240|247240|  Volgarr the Viking|        1225|  440.7918367346939|45.201632653061225|   838.2881632653061|         1.6138775510204082|     577.1983673469388| 1.493205077054694E9|
# |https://store.ste...|  app|American Truck Si...|Experience legend...|Very Positive,(45...|Very Positive,(21...|        null|        SCS Software|SCS Software,SCS ...|Simulation,Drivin...|Single-player,Ste...|English,French,It...|          51|    Indie,Simulation| About This Game ...|                null|Minimum:,OS:,Wind...|    Recommended:,OS:,...|        $19.99|        $34.26| 270880|270880|American Truck Si...|       56685|  91.14898121196083| 8.553832583575902|  12869.879527211784|         184.74460615683162|    6348.9398253506215|1.5948071056653435E9|
# |https://store.ste...|  app|            The Room|A mysterious invi...|Very Positive,(87...|Overwhelmingly Po...|        null|     Fireproof Games|Fireproof Games,F...|Puzzle,Mystery,Po...|Single-player,Ste...|English,French,It...|           5|     Adventure,Indie| About This Game ...|                null|                null|                    null|         $4.99|          null| 288160|288160|            The Room|       10679|   269.046352654743| 20.55239254611855|   309.3891750163873|         3.2245528607547524|     251.3481599400693|1.5383939767603707E9|
# |https://store.ste...|  app|         Pit People®|In this fast-pace...|Very Positive,(16...|Very Positive,(4,...|        null|        The Behemoth|The Behemoth,The ...|Strategy,Funny,Tu...|Single-player,Mul...|English,French,It...|          27|Action,Indie,RPG,...| About This Game ...|                null|                null|                    null|        $19.99|        $29.56| 291860|291860|          Pit People|        4682| 207.12921828278513|  18.2052541648868|  2211.9651858180264|          9.840452797949593|    1317.8596753524134|1.5558878551593337E9|
# |https://store.ste...|  app|The Elder Scrolls...|Join over 10 mill...|Mixed,(797),- 68%...|Mostly Positive,(...|        null|Zenimax Online St...|Bethesda Softwork...|RPG,MMORPG,Open W...|MMO,Steam Trading...|English,French,Ge...|        null|Massively Multipl...| About This Game ...|                null|Minimum:,OS:,Wind...|    Recommended:,OS:,...|        $19.99|         $9.99| 306130|306130|The Elder Scrolls...|       67844| 121.03323801662638|   9.9339661576558|  31350.782574730263|          345.0057190024173|    15164.116016154709|1.5810567849933376E9|
# |https://store.ste...|  app|Styx: Shards of D...|Styx returns in a...|Very Positive,(10...|Very Positive,(1,...|        null|      Cyanide Studio|Focus Home Intera...|Stealth,Adventure...|Single-player,Onl...|English,French,It...|          38|    Action,Adventure| About This Game ...|                null|Minimum:,Requires...|    Recommended:,Requ...|        $39.99|          null| 355790|355790|Styx: Shards of D...|        1809|  233.5632946379215| 28.92482034273079|  1382.2388059701493|           9.18629076838032|    1008.5671641791045|1.5600841833852956E9|
# |https://store.ste...|  app|           Undertale|UNDERTALE! The RP...|Very Positive,(59...|Overwhelmingly Po...|        null|             tobyfox|     tobyfox,tobyfox|Great Soundtrack,...|Single-player,Ste...|    English,Japanese|        null|           Indie,RPG| About This Game ...|                null|Minimum:,OS:,Wind...|    Recommended:,OS:,...|         $9.99|          null| 391540|391540|           Undertale|      100008| 126.02838772898168|  9.77888768898488|  2032.3916786657066|          17.15445764338853|    1321.1630369570435|1.5512469985223582E9|
# |https://store.ste...|  app|   Hearts of Iron IV|Victory is at you...|Very Positive,(89...|Very Positive,(30...|        null|Paradox Developme...|Paradox Interacti...|Strategy,World Wa...|Single-player,Mul...|English,French,Ge...|          92| Simulation,Strategy| About This Game ...|                null|Minimum:,OS:,Wind...|    Recommended:,OS:,...|        $39.99|        $94.45| 394360|394360|   Hearts of Iron IV|       92401|  90.87554247248407| 7.782047813335353|   33643.08647092564|          486.0712871072824|     17944.21936992024| 1.603755913324228E9|
# |https://store.ste...|  app|      Super Meat Boy|The infamous, tou...|Very Positive,(67...|Very Positive,(18...|        null|           Team Meat|                null|Platformer,Diffic...|Single-player,Ste...|     English,Russian|          48|               Indie| About This Game ...|                null|                null|                    null|        $14.99|        $40.10|  40800| 40800|      Super Meat Boy|       20637|  272.2860396375442|21.883510200125986|   1156.138682948103|          8.258467800552406|     772.4873285845811| 1.504364818514319E9|
# +--------------------+-----+--------------------+--------------------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+------------------------+--------------+--------------+-------+------+--------------------+------------+-------------------+------------------+--------------------+---------------------------+----------------------+--------------------+
# only showing top 10 rows

# %%
playerType_steamGames.count()
# Out:
# 282

# %% [markdown]
# ## Genres Analysis

# %%
genres_map = steam_games.select("game_id", F.explode_outer(F.split(col("genre"),",")).alias("genres")) \
                        .drop("genre") \
                        .where(col("genres") != F.lit("null"))

genres = genres_map.select("genres").distinct()


genres_map.show(10)

genres.show(10)

print("Number of genres:", genres.count())
# Out:
# +-------+--------------------+
# |game_id|              genres|
# +-------+--------------------+
# | 674020|              Action|
# | 674020|               Indie|
# | 674020|        Early Access|
# | 389430|              Action|
# | 389430|           Adventure|
# | 389430|        Free to Play|
# | 389430|Massively Multipl...|
# | 389430|                 RPG|
# | 414870|               Indie|
# | 414870|          Simulation|
# +-------+--------------------+
# only showing top 10 rows
#
# +--------------------+
# |              genres|
# +--------------------+
# |Cross-Platform Mu...|
# |                  51|
# |                1500|
# |           Difficult|
# |              Runner|
# |           Education|
# |        City Builder|
# |                  15|
# |      Steam Workshop|
# |           阿屁PP314|
# +--------------------+
# only showing top 10 rows
#
# Number of genres: 265

# %%
playerTypeByGenres = playerType.select("app_id", "review_count", "avg_num_games_owned", "avg_playtime_forever") \
                                .join(genres_map, genres_map["game_id"] == playerType["app_id"]) \
                                .drop("game_id") \
                                .withColumn("games_owned", col("avg_num_games_owned") * col("review_count")) \
                                .withColumn("playtime", col("avg_playtime_forever") * col("review_count")) \
                                .drop("avg_num_games_owned", "avg_playtime_forever")

playerTypeByGenres = playerTypeByGenres.groupBy("genres").agg( \
                                                                F.sum(col("review_count")).alias("total_review_count"), \
                                                                F.sum(col("games_owned")).alias("total_games_owned"), \
                                                                F.sum(col("playtime")).alias("total_playtime"), \
                                                            ) \
                                        .withColumn("avg_games_owned", col("total_games_owned") / col("total_review_count")) \
                                        .withColumn("avg_playtime", col("total_playtime") / col("total_review_count"))

# %%
playerTypeByGenres.orderBy(F.desc("avg_games_owned")).show(20)
# Out:
# +--------------------+------------------+-----------------+----------------+------------------+------------------+
# |              genres|total_review_count|total_games_owned|  total_playtime|   avg_games_owned|      avg_playtime|
# +--------------------+------------------+-----------------+----------------+------------------+------------------+
# |            Strategy|           2058413|     3.05925249E8| 3.8837774008E10|148.62189900666192|18867.823905115252|
# |        Early Access|            618693|      8.3312815E7|    5.99215351E9|134.65937872256515| 9685.180711596866|
# |                 RPG|           4032002|     5.05164663E8| 6.8547185582E10|125.28879276349565|17000.781641973394|
# |               Indie|           5885382|     7.02113375E8| 9.4790444046E10|119.29784251897328|16106.081822046555|
# |        Free to Play|            108306|      1.2823618E7|    1.79454123E8|118.40173212933725|1656.9176499916903|
# |          Simulation|           3211194|     3.55088611E8| 5.7704515753E10| 110.5783739630804| 17969.80056421381|
# |              Action|          10019635|     1.10702985E9|1.93785289253E11|110.48604564936747|19340.553748015773|
# |              Casual|            855243|      9.2735258E7|   3.800259968E9|108.43147269255638| 4443.485615199423|
# |           Adventure|           6649933|     6.91483295E8| 1.2294599946E11|103.98349802922826|18488.306492712032|
# |              Sports|            514344|      5.1089234E7| 1.4391855195E10|  99.3289199446285|27980.991700107323|
# |              Racing|            488919|      4.7023028E7| 1.3898995876E10| 96.17754270134726|28428.013384630172|
# |Animation & Modeling|            248580|      2.0185733E7|   1.611550123E9|  81.2041716952289| 6483.024068710274|
# |Design & Illustra...|            248580|      2.0185733E7|   1.611550123E9|  81.2041716952289| 6483.024068710274|
# |           Utilities|            248580|      2.0185733E7|   1.611550123E9|  81.2041716952289| 6483.024068710274|
# |         Steam Cloud|              6991|         559705.0|     1.2960002E7| 80.06079244743242|1853.8123301387498|
# |  Local Multi-Player|              6991|         559705.0|     1.2960002E7| 80.06079244743242|1853.8123301387498|
# |Full controller s...|              6991|         559705.0|     1.2960002E7| 80.06079244743242|1853.8123301387498|
# |        Multi-player|              6991|         559705.0|     1.2960002E7| 80.06079244743242|1853.8123301387498|
# |        Online Co-op|              6991|         559705.0|     1.2960002E7| 80.06079244743242|1853.8123301387498|
# | Steam Trading Cards|              6991|         559705.0|     1.2960002E7| 80.06079244743242|1853.8123301387498|
# +--------------------+------------------+-----------------+----------------+------------------+------------------+
# only showing top 20 rows

# %%
genres_gamesOwned_vs_playtime = playerTypeByGenres.select("genres", "avg_games_owned", "avg_playtime")
genres_gamesOwned_vs_playtime.toPandas().plot.scatter(x='avg_playtime', y='avg_games_owned')
print(genres_gamesOwned_vs_playtime.toPandas().corr())
# Out:
#                  avg_games_owned  avg_playtime
# avg_games_owned         1.000000      0.336969
# avg_playtime            0.336969      1.000000
# /var/folders/bn/n488fsxn7ndc1kw3hf1k47000000gn/T/ipykernel_22689/1944477113.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(genres_gamesOwned_vs_playtime.toPandas().corr())

# %% [markdown]
# ## Popular Tags Analysis

# %%
tags_map = steam_games.select("game_id", F.explode_outer(F.split(col("popular_tags"),",")).alias("tags")) \
                        .drop("popular_tags") \
                        .where(col("tags") != F.lit("null"))

tags = tags_map.select("tags").distinct()


tags_map.show(10)

tags.show(10)

print("Number of tags:", tags.count())
# Out:
# +-------+------------+
# |game_id|        tags|
# +-------+------------+
# | 674020|Early Access|
# | 674020|         FPS|
# | 674020|    Military|
# | 674020|         War|
# | 674020| Multiplayer|
# | 674020|Early Access|
# | 674020|     Shooter|
# | 674020|      Action|
# | 674020|First-Person|
# | 674020|   Realistic|
# +-------+------------+
# only showing top 10 rows
#
# +--------------------+
# |                tags|
# +--------------------+
# |   Schmidt Workshops|
# |    Carpe Fulgur LLC|
# | Iceberg Interactive|
# |             Match 3|
# |Project ""The Gam...|
# |Tunnel Vision Studio|
# |              Nov 27|
# |Heart Shaped Game...|
# |   Specialbit Studio|
# |      1 user reviews|
# +--------------------+
# only showing top 10 rows
#
# Number of tags: 967

# %%
playerTypeByTags = playerType.select("app_id", "review_count", "avg_num_games_owned", "avg_playtime_forever") \
                            .join(tags_map, tags_map["game_id"] == playerType["app_id"]) \
                            .drop("game_id") \
                            .withColumn("games_owned", col("avg_num_games_owned") * col("review_count")) \
                            .withColumn("playtime", col("avg_playtime_forever") * col("review_count")) \
                            .drop("avg_num_games_owned", "avg_playtime_forever")

playerTypeByTags = playerTypeByTags.groupBy("tags").agg( \
                                                            F.sum(col("review_count")).alias("total_review_count"), \
                                                            F.sum(col("games_owned")).alias("total_games_owned"), \
                                                            F.sum(col("playtime")).alias("total_playtime"), \
                                                        ) \
                                    .withColumn("avg_games_owned", col("total_games_owned") / col("total_review_count")) \
                                    .withColumn("avg_playtime", col("total_playtime") / col("total_review_count"))

# %%
playerTypeByTags.orderBy(F.desc("avg_playtime")).show(20)
# Out:
# +--------------------+------------------+-----------------+--------------------+------------------+------------------+
# |                tags|total_review_count|total_games_owned|      total_playtime|   avg_games_owned|      avg_playtime|
# +--------------------+------------------+-----------------+--------------------+------------------+------------------+
# |              MMORPG|            463851|      4.6801101E7|      1.896003512E10|100.89684187379137| 40875.27055024135|
# |           Political|             95021|      1.4404076E7|       3.468652055E9|151.58834362930298| 36504.05757674619|
# |           Dinosaurs|            402674|      3.8452236E7|1.432441192600000...| 95.49222447935551| 35573.22282044533|
# |       Battle Royale|           1449293|      8.1423648E7|      5.074327672E10| 56.18163338952165|35012.434835468055|
# |           Diplomacy|            293407|      3.9465453E7|      1.003682946E10| 134.5075373116524|34207.873227291784|
# |            Baseball|               490|64514.00000000001|         1.6271878E7|131.66122448979593| 33207.91428571429|
# |              Soccer|            409954|      4.1037919E7|     1.3482984675E10|100.10371651453578|32889.018463047076|
# |            Football|            409954|      4.1037919E7|     1.3482984675E10|100.10371651453578|32889.018463047076|
# |         Competitive|           2786929|     2.03937801E8|     8.8874071664E10|  73.1765326637313|31889.607400834397|
# |             Dragons|            440508|      4.3436895E7|1.344763106100000...| 98.60637037238824|30527.552419025313|
# |           Education|            119652|      1.4912938E7|       3.640162756E9|124.63592752315047|30422.916089994316|
# |          Team-Based|           3467683|     2.64358016E8|    1.05185630954E11| 76.23477001790533|30333.116076065777|
# |      4 Player Local|            449613|      4.7205934E7|     1.3276083218E10|104.99236899288944| 29527.80106002273|
# |Massively Multipl...|           2112202|     1.93777887E8|     6.0187334509E10| 91.74211888825027| 28495.06558037536|
# |            Military|            695876|      8.1443068E7|     1.9820852245E10|117.03675367450523|28483.310597002914|
# |                 PvP|           2861938|      2.0697915E8|     8.1200610435E10| 72.32132561921327|28372.595924509897|
# |            Tactical|           3590960|     3.18951882E8|    1.00039720387E11| 88.82078385724152|  27858.7676796734|
# |                 Mod|            694986|      6.3477116E7|     1.9244601934E10| 91.33581971435396| 27690.63252209397|
# |        Split Screen|            500610|      4.7659221E7|     1.3313992223E10| 95.20229519985618|26595.537889774474|
# |Third-Person Shooter|           2937070|     2.41619851E8|     7.7117568232E10| 82.26560858270317|26256.632709468962|
# +--------------------+------------------+-----------------+--------------------+------------------+------------------+
# only showing top 20 rows

# %%
playtime_by_review = playerTypeByTags.select("tags", "avg_playtime").orderBy("avg_playtime", ascending=False).limit(20)
playtime_by_review.toPandas().plot.bar(x="tags",
                                        y="avg_playtime", figsize=(12, 5),
                                        title="Average Playtime for each Genre",
                                        xlabel = "Genres",
                                        ylabel = "Average Playtime")
# Out:
# <AxesSubplot:title={'center':'Average Playtime for each Genre'}, xlabel='Genres', ylabel='Average Playtime'>

# %%
tags_gamesOwned_vs_playtime = playerTypeByTags.select("tags", "avg_games_owned", "avg_playtime")
tags_gamesOwned_vs_playtime.toPandas().plot.scatter(x='avg_playtime', y='avg_games_owned')
print(tags_gamesOwned_vs_playtime.toPandas().corr())
# Out:
#                  avg_games_owned  avg_playtime
# avg_games_owned         1.000000     -0.525954
# avg_playtime           -0.525954      1.000000
# /var/folders/bn/n488fsxn7ndc1kw3hf1k47000000gn/T/ipykernel_22689/1547959008.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(tags_gamesOwned_vs_playtime.toPandas().corr())
